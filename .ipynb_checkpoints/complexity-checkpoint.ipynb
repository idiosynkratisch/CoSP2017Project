# %%
from swda_time import CorpusReader
from random import randrange
import complexity
from nltk.tree import Tree

corpus = CorpusReader('swda', 'swda/swda-metadata.csv')

# %%
#find a random example and compute the non-normalized measures
iterator = corpus.iter_utterances()

for i in range(randrange(1000)):
    s = iterator.next()

for tree in s.trees:
    print tree
    print 'Length: {}'.format(complexity.length(tree))
    print 'Depth: {}'.format(complexity.depth(tree))
    print 'Width: {}'.format(complexity.width(tree))
    print 'Depth*width: {}'.format(complexity.balanced(tree))
    print 'Average depth: {}'.format(complexity.avdepth(tree))
# Out:
# utterance 755
# (S
#   (EDITED
#     (RM (-DFL- \[))
#     (S (NP-SBJ (PRP It)) (VP-UNF (BES 's)))
#     (, ,)
#     (IP (-DFL- \+)))
#   (INTJ (UH uh))
#   (, ,)
#   (NP-SBJ (PRP it))
#   (RS (-DFL- \]))
#   (VP
#     (VP
#       (VBZ saves)
#       (NP (NP (DT a) (JJ third)) (ADVP (RP off)))
#       (PP (IN on) (NP (NNS taxes))))
#     (CC or)
#     (NP-ETC (NN something)))
#   (. .)
#   (-DFL- E_S))
# Length: 18
# Depth: 7
# Width: 1.48648648649
# Depth*width: 10.4054054054
# Average depth: 5.0

# %%
#print the normalized measures for the random example
for tree in s.trees:
    print 'Normalized depth: {}'.format(complexity.ndepth(tree))
    print 'Normalized width: {}'.format(complexity.nwidth(tree))
    print 'Normalized depth*width: {}'.format(complexity.nbalanced(tree))
    print 'Normalized average depth: {}'.format(complexity.n_avdepth(tree))
# Out:
# Normalized depth: 0.742479858893
# Normalized width: 0.98451899703
# Normalized depth*width: 0.733494619043
# Normalized average depth: 0.821923933881

# %%
# dict with the measures for easy iteration
measures = {'normalized depth': complexity.ndepth,
            'normalized width': complexity.nwidth,
            'normalized depth*width': complexity.nbalanced,
            'normalized average depth': complexity.n_avdepth}

# dict of sets (to avoid duplicates) for the results
results = dict([(measure, []) for measure in measures])

for conv in corpus.iter_transcripts(display_progress=False):
    for utt in conv.utterances:
        for tree in utt.trees:
            #Trees need to be cast to string to be hashable for duplicate removal
            string = str(tree)
            for measure in measures:
                results[measure].append((conv.conversation_no, measures[measure](tree), string))

for measure in results:
    results[measure] = list(set(results[measure]))
    results[measure].sort(key=lambda x: x[1])

av_results = {}
for measure in measures:
    av_results[measure] = sorted(results[measure], key=lambda x: abs(x[1] - 1))

# %%
# modifiers with associated functions
mods = {'Most': lambda x: x[len(x)-10:], 'Least': lambda x: x[:10]}

for measure in measures:
    for modifier in mods:
        print '{} complex trees by {}:\n'.format(modifier, measure)
        for i, item in enumerate(mods[modifier](results[measure]), 1):
            tree = Tree.fromstring(item[2])
            text = str(tree.flatten()).replace('\n', '')
            print '{}.(from conv. no. {}) {} \n {}'.format(i, item[0], text, tree)
        print '\n'

for measure in av_results:
    print 'Closest to average trees by {}'.format(measure)
    for i, item in enumerate(av_results[measure][:10], 1):
        tree = Tree.fromstring(item[2])
        text = str(tree.flatten()).replace('\n', '')
        print '{}.(from conv. no. {}) {} \n {}'.format(i, item[0], text, tree)
# Out:
# Most complex trees by normalized depth:
#
# 1.(from conv. no. 2405) (S  but  it  's  running  about  seventy  which  *T*-1  is  still  ridiculous  *  to  have  *-3  to  make  changes  to  seventy  percent  of  everything  that  she  types  *T*-2  .  E_S)
#  (S
#   (CC but)
#   (NP-SBJ (PRP it))
#   (VP
#     (BES 's)
#     (VP
#       (VBG running)
#       (NP
#         (NP (RB about) (CD seventy))
#         (SBAR
#           (WHNP-1 (WDT which))
#           (S
#             (NP-SBJ (-NONE- *T*-1))
#             (VP
#               (VBZ is)
#               (ADVP (RB still))
#               (ADJP-PRD
#                 (JJ ridiculous)
#                 (S
#                   (NP-SBJ-3 (-NONE- *))
#                   (VP
#                     (TO to)
#                     (VP
#                       (VB have)
#                       (S
#                         (NP-SBJ (-NONE- *-3))
#                         (VP
#                           (TO to)
#                           (VP
#                             (VB make)
#                             (NP (NNS changes))
#                             (PP
#                               (IN to)
#                               (NP
#                                 (NP (CD seventy) (NN percent))
#                                 (PP
#                                   (IN of)
#                                   (NP
#                                     (NP (NN everything))
#                                     (SBAR
#                                       (WHNP-2 (WDT that))
#                                       (S
#                                         (NP-SBJ (PRP she))
#                                         (VP
#                                           (VBZ types)
#                                           (NP (-NONE- *T*-2))))))))))))))))))))))
#   (. .)
#   (-DFL- E_S))
# 2.(from conv. no. 2545) (S  Actually  ,  it  would  be  worth  it  ,  if  he  were  able  *-1  to  get  a  program  that  *T*-2  would  do  something  that  he  normally  had  *-3  to  do  *T*-4  by  hand  .  E_S)
#  (S
#   (INTJ (UH Actually))
#   (, ,)
#   (NP-SBJ (PRP it))
#   (VP
#     (MD would)
#     (VP
#       (VB be)
#       (ADJP-PRD (JJ worth) (NP (PRP it)))
#       (, ,)
#       (SBAR-ADV
#         (IN if)
#         (S
#           (NP-SBJ-1 (PRP he))
#           (VP
#             (VBD were)
#             (ADJP-PRD
#               (JJ able)
#               (S
#                 (NP-SBJ (-NONE- *-1))
#                 (VP
#                   (TO to)
#                   (VP
#                     (VB get)
#                     (NP
#                       (NP (DT a) (NN program))
#                       (SBAR
#                         (WHNP-2 (WDT that))
#                         (S
#                           (NP-SBJ (-NONE- *T*-2))
#                           (VP
#                             (MD would)
#                             (VP
#                               (VB do)
#                               (NP
#                                 (NP (NN something))
#                                 (SBAR
#                                   (WHNP-4 (WDT that))
#                                   (S
#                                     (NP-SBJ-3 (PRP he))
#                                     (ADVP (RB normally))
#                                     (VP
#                                       (VBD had)
#                                       (S
#                                         (NP-SBJ (-NONE- *-3))
#                                         (VP
#                                           (TO to)
#                                           (VP
#                                             (VB do)
#                                             (NP (-NONE- *T*-4))
#                                             (PP
#                                               (IN by)
#                                               (NP (NN hand))))))))))))))))))))))))
#   (. .)
#   (-DFL- E_S))
# 3.(from conv. no. 2382) (S  I  think  0  they  feel  0  this  is  going  *-1  to  be  an  effortless  sweatless  way  ,  0  *  to  get  in  shape  ,  without  *  having  *-3  to  spend  anything  *T*-2  E_S)
#  (S
#   (NP-SBJ (PRP I))
#   (VP
#     (VBP think)
#     (SBAR
#       (-NONE- 0)
#       (S
#         (NP-SBJ (PRP they))
#         (VP
#           (VBP feel)
#           (SBAR
#             (-NONE- 0)
#             (S
#               (NP-SBJ-1 (DT this))
#               (VP
#                 (VBZ is)
#                 (VP
#                   (VBG going)
#                   (S
#                     (NP-SBJ (-NONE- *-1))
#                     (VP
#                       (TO to)
#                       (VP
#                         (VB be)
#                         (NP-PRD
#                           (NP
#                             (DT an)
#                             (JJ effortless)
#                             (JJ sweatless)
#                             (NN way))
#                           (, ,)
#                           (SBAR
#                             (WHADVP-2 (-NONE- 0))
#                             (S
#                               (NP-SBJ (-NONE- *))
#                               (VP
#                                 (TO to)
#                                 (VP
#                                   (VB get)
#                                   (PP (IN in) (NP (NN shape)))
#                                   (, ,)
#                                   (PP
#                                     (IN without)
#                                     (S-NOM
#                                       (NP-SBJ-3 (-NONE- *))
#                                       (VP
#                                         (VBG having)
#                                         (S
#                                           (NP-SBJ (-NONE- *-3))
#                                           (VP
#                                             (TO to)
#                                             (VP
#                                               (VB spend)
#                                               (NP (NN anything))))))))
#                                   (ADVP-MNR (-NONE- *T*-2))))))))))))))))))
#   (-DFL- E_S))
# 4.(from conv. no. 4108) (S  I  think  0  that  's  also  where  you  're  going  *-1  to  have  a  lot  of  people  who  *T*-2  are  going  *-3  to  *T*-4  ,  N_S)
#  (S
#   (NP-SBJ (PRP I))
#   (VP
#     (VBP think)
#     (SBAR
#       (-NONE- 0)
#       (S
#         (NP-SBJ (DT that))
#         (VP
#           (BES 's)
#           (ADVP (RB also))
#           (SBAR-LOC-PRD
#             (WHADVP-4 (WRB where))
#             (S
#               (NP-SBJ-1 (PRP you))
#               (VP
#                 (VBP 're)
#                 (VP
#                   (VBG going)
#                   (S
#                     (NP-SBJ (-NONE- *-1))
#                     (VP
#                       (TO to)
#                       (VP
#                         (VB have)
#                         (NP
#                           (NP (DT a) (NN lot))
#                           (PP
#                             (IN of)
#                             (NP
#                               (NP (NNS people))
#                               (SBAR
#                                 (WHNP-2 (WP who))
#                                 (S
#                                   (NP-SBJ-3 (-NONE- *T*-2))
#                                   (VP
#                                     (VBP are)
#                                     (VP
#                                       (VBG going)
#                                       (S
#                                         (NP-SBJ (-NONE- *-3))
#                                         (VP-UNF (TO to))))))))))
#                         (ADVP (-NONE- *T*-4)))))))))))))
#   (, ,)
#   (-DFL- N_S))
# 5.(from conv. no. 2521) (S  it  was  right  close  to  when  we  was  going  *-1  to  find  out  if  we  was  going  *-2  to  get  *-3  to  be  in  the  playoffs  ,  or  not  *T*-4  .  E_S)
#  (S
#   (NP-SBJ (PRP it))
#   (VP
#     (VBD was)
#     (ADVP-LOC-PRD
#       (RB right)
#       (RB close)
#       (PP
#         (IN to)
#         (SBAR-TMP
#           (WHADVP-4 (WRB when))
#           (S
#             (NP-SBJ-1 (PRP we))
#             (VP
#               (VBD was)
#               (VP
#                 (VBG going)
#                 (S
#                   (NP-SBJ (-NONE- *-1))
#                   (VP
#                     (TO to)
#                     (VP
#                       (VB find)
#                       (PRT (RP out))
#                       (SBAR
#                         (IN if)
#                         (S
#                           (NP-SBJ-2 (PRP we))
#                           (VP
#                             (VBD was)
#                             (VP
#                               (VBG going)
#                               (S
#                                 (NP-SBJ-3 (-NONE- *-2))
#                                 (VP
#                                   (TO to)
#                                   (VP
#                                     (VP
#                                       (VB get)
#                                       (S
#                                         (NP-SBJ (-NONE- *-3))
#                                         (VP
#                                           (TO to)
#                                           (VP
#                                             (VB be)
#                                             (PP-PRD
#                                               (IN in)
#                                               (NP
#                                                 (DT the)
#                                                 (NNS playoffs)))))))
#                                     (, ,)
#                                     (CC or)
#                                     (VP (FRAG (RB not))))))))))
#                       (ADVP-TMP (-NONE- *T*-4))))))))))))
#   (. .)
#   (-DFL- E_S))
# 6.(from conv. no. 3328) (S  I  guess  0  they  figure  0  they  're  going  *-1  to  make  up  for  all  0  they  did  n't  get  *T*-3  when  they  should  have  had  a  budget  *T*-2  .  E_S)
#  (S
#   (NP-SBJ (PRP I))
#   (VP
#     (VBP guess)
#     (SBAR
#       (-NONE- 0)
#       (S
#         (NP-SBJ (PRP they))
#         (VP
#           (VBP figure)
#           (SBAR
#             (-NONE- 0)
#             (S
#               (NP-SBJ-1 (PRP they))
#               (VP
#                 (VBP 're)
#                 (VP
#                   (VBG going)
#                   (S
#                     (NP-SBJ (-NONE- *-1))
#                     (VP
#                       (TO to)
#                       (VP
#                         (VB make)
#                         (PRT (RP up))
#                         (PP
#                           (IN for)
#                           (NP
#                             (NP (DT all))
#                             (SBAR
#                               (WHNP-3 (-NONE- 0))
#                               (S
#                                 (NP-SBJ (PRP they))
#                                 (VP
#                                   (VBD did)
#                                   (RB n't)
#                                   (VP
#                                     (VB get)
#                                     (NP (-NONE- *T*-3))
#                                     (SBAR-TMP
#                                       (WHADVP-2 (WRB when))
#                                       (S
#                                         (NP-SBJ (PRP they))
#                                         (VP
#                                           (MD should)
#                                           (VP
#                                             (VB have)
#                                             (VP
#                                               (VBN had)
#                                               (NP (DT a) (NN budget))
#                                               (ADVP-TMP
#                                                 (-NONE- *T*-2))))))))))))))))))))))))
#   (. .)
#   (-DFL- E_S))
# 7.(from conv. no. 3646) (S  Well  ,  I  had  one  that  *T*-1  was  needed  *-2  to  be  able  *-3  to  be  moved  *-4  along  \[  at  a  ,  \+  at  a  \]  pace  a  little  faster  than  he  was  going  *-5  to  be  able  *-6  to  be  moved  *-7  in  public  school  ,  E_S)
#  (S
#   (INTJ (UH Well))
#   (, ,)
#   (NP-SBJ (PRP I))
#   (VP
#     (VBD had)
#     (NP
#       (NP (NN one))
#       (SBAR
#         (WHNP-1 (WDT that))
#         (S
#           (NP-SBJ-2 (-NONE- *T*-1))
#           (EDITED (VP-UNF (VBD was)))
#           (VP
#             (VBN needed)
#             (S
#               (NP-SBJ-3 (-NONE- *-2))
#               (VP
#                 (TO to)
#                 (VP
#                   (VB be)
#                   (ADJP-PRD
#                     (JJ able)
#                     (S
#                       (NP-SBJ-4 (-NONE- *-3))
#                       (VP
#                         (TO to)
#                         (VP
#                           (VB be)
#                           (VP
#                             (VBN moved)
#                             (NP (-NONE- *-4))
#                             (ADVP (RB along))
#                             (EDITED
#                               (RM (-DFL- \[))
#                               (PP (IN at) (NP-UNF (DT a)))
#                               (, ,)
#                               (IP (-DFL- \+)))
#                             (PP
#                               (IN at)
#                               (NP
#                                 (NP (DT a) (RS (-DFL- \])) (NN pace))
#                                 (ADJP
#                                   (ADJP
#                                     (NP-ADV (DT a) (RB little))
#                                     (RB faster))
#                                   (SBAR
#                                     (IN than)
#                                     (S
#                                       (NP-SBJ-5 (PRP he))
#                                       (VP
#                                         (VBD was)
#                                         (VP
#                                           (VBG going)
#                                           (S
#                                             (NP-SBJ-6 (-NONE- *-5))
#                                             (VP
#                                               (TO to)
#                                               (VP
#                                                 (VB be)
#                                                 (ADJP-PRD
#                                                   (JJ able)
#                                                   (S
#                                                     (NP-SBJ-7
#                                                       (-NONE- *-6))
#                                                     (VP
#                                                       (TO to)
#                                                       (VP
#                                                         (VB be)
#                                                         (VP
#                                                           (VBN moved)
#                                                           (NP
#                                                             (-NONE-
#                                                               *-7))
#                                                           (PP
#                                                             (IN in)
#                                                             (NP
#                                                               (JJ
#                                                                 public)
#                                                               (NN
#                                                                 school)))))))))))))))))))))))))))))))
#   (, ,)
#   (-DFL- E_S))
# 8.(from conv. no. 3573) (S  and  I  think  that  \[  it  's  ,  \+  it  's  \]  very  surprising  0  some  of  these  very  expensive  Volvos  can  be  gotten  *-1  for  a  lot  less  money  than  you  would  think  if  you  're  willing  *-2  to  buy  ones  that  *T*-3  are  about  ,  the  vintage  of  the  cars  that  you  and  I  currently  own  *T*-4  E_S)
#  (S
#   (CC and)
#   (NP-SBJ (PRP I))
#   (VP
#     (VBP think)
#     (SBAR
#       (IN that)
#       (S
#         (EDITED
#           (RM (-DFL- \[))
#           (S (NP-SBJ (PRP it)) (VP-UNF (BES 's)))
#           (, ,)
#           (IP (-DFL- \+)))
#         (NP-SBJ (PRP it))
#         (VP
#           (BES 's)
#           (RS (-DFL- \]))
#           (ADJP-PRD
#             (RB very)
#             (JJ surprising)
#             (SBAR
#               (-NONE- 0)
#               (S
#                 (NP-SBJ-1
#                   (NP (DT some))
#                   (PP
#                     (IN of)
#                     (NP
#                       (DT these)
#                       (ADJP (RB very) (JJ expensive))
#                       (NNPS Volvos))))
#                 (VP
#                   (MD can)
#                   (VP
#                     (VB be)
#                     (VP
#                       (VBN gotten)
#                       (NP (-NONE- *-1))
#                       (PP
#                         (IN for)
#                         (NP
#                           (NP
#                             (DT a)
#                             (ADJP (NN lot) (JJR less))
#                             (NN money))
#                           (SBAR
#                             (IN than)
#                             (S
#                               (NP-SBJ (PRP you))
#                               (VP
#                                 (MD would)
#                                 (VP
#                                   (VB think)
#                                   (SBAR-ADV
#                                     (IN if)
#                                     (S
#                                       (NP-SBJ-2 (PRP you))
#                                       (VP
#                                         (VBP 're)
#                                         (ADJP-PRD
#                                           (JJ willing)
#                                           (S
#                                             (NP-SBJ (-NONE- *-2))
#                                             (VP
#                                               (TO to)
#                                               (VP
#                                                 (VB buy)
#                                                 (NP
#                                                   (NP (NNS ones))
#                                                   (SBAR
#                                                     (WHNP-3
#                                                       (WDT that))
#                                                     (S
#                                                       (NP-SBJ
#                                                         (-NONE-
#                                                           *T*-3))
#                                                       (VP
#                                                         (VBP are)
#                                                         (ADVP
#                                                           (RB about))
#                                                         (, ,)
#                                                         (NP-PRD
#                                                           (NP
#                                                             (DT the)
#                                                             (NN
#                                                               vintage))
#                                                           (PP
#                                                             (IN of)
#                                                             (NP
#                                                               (NP
#                                                                 (DT
#                                                                   the)
#                                                                 (NNS
#                                                                   cars))
#                                                               (SBAR
#                                                                 (WHNP-4
#                                                                   (WDT
#                                                                     that))
#                                                                 (S
#                                                                   (NP-SBJ
#                                                                     (PRP
#                                                                       you)
#                                                                     (CC
#                                                                       and)
#                                                                     (PRP
#                                                                       I))
#                                                                   (ADVP-TMP
#                                                                     (RB
#                                                                       currently))
#                                                                   (VP
#                                                                     (VBP
#                                                                       own)
#                                                                     (NP
#                                                                       (-NONE-
#                                                                         *T*-4)))))))))))))))))))))))))))))))))))
#   (-DFL- E_S))
# 9.(from conv. no. 2832) (S  I  figured  0  I  'm  going  *-1  to  have  *-2  to  hire  somebody  0  *T*-3  to  remove  our  windows  and  put  new  ones  *ICH*-6  in  that  *T*-4  are  easier  0  *  to  clean  *T*-5  .  E_S)
#  (S
#   (NP-SBJ (PRP I))
#   (VP
#     (VBD figured)
#     (SBAR
#       (-NONE- 0)
#       (S
#         (NP-SBJ-1 (PRP I))
#         (VP
#           (VBP 'm)
#           (VP
#             (VBG going)
#             (S
#               (NP-SBJ-2 (-NONE- *-1))
#               (VP
#                 (TO to)
#                 (VP
#                   (VB have)
#                   (S
#                     (NP-SBJ (-NONE- *-2))
#                     (VP
#                       (TO to)
#                       (VP
#                         (VB hire)
#                         (NP
#                           (NP (NN somebody))
#                           (SBAR-PRP
#                             (WHNP-3 (-NONE- 0))
#                             (S
#                               (NP-SBJ (-NONE- *T*-3))
#                               (VP
#                                 (TO to)
#                                 (VP
#                                   (VP
#                                     (VB remove)
#                                     (NP (PRP$ our) (NNS windows)))
#                                   (CC and)
#                                   (VP
#                                     (VB put)
#                                     (NP
#                                       (NP (JJ new) (NNS ones))
#                                       (SBAR (-NONE- *ICH*-6)))
#                                     (PRT (IN in))
#                                     (SBAR-6
#                                       (WHNP-4 (WDT that))
#                                       (S
#                                         (NP-SBJ (-NONE- *T*-4))
#                                         (VP
#                                           (VBP are)
#                                           (ADJP-PRD
#                                             (JJR easier)
#                                             (SBAR
#                                               (WHNP-5 (-NONE- 0))
#                                               (S
#                                                 (NP-SBJ (-NONE- *))
#                                                 (VP
#                                                   (TO to)
#                                                   (VP
#                                                     (VB clean)
#                                                     (NP
#                                                       (-NONE- *T*-5)))))))))))))))))))))))))))
#   (. .)
#   (-DFL- E_S))
# 10.(from conv. no. 3235) (S  and  I  think  0  it  's  going  *-1  to  have  *-2  to  swing  back  the  other  way  ,  because  I  think  0  we  're  going  *-3  to  have  an  awful  lot  of  kids  who  *T*-4  are  going  *-5  to  have  major  problems  from  all  this  .  E_S)
#  (S
#   (CC and)
#   (NP-SBJ (PRP I))
#   (VP
#     (VBP think)
#     (SBAR
#       (-NONE- 0)
#       (S
#         (NP-SBJ-1 (PRP it))
#         (VP
#           (BES 's)
#           (VP
#             (VBG going)
#             (S
#               (NP-SBJ-2 (-NONE- *-1))
#               (VP
#                 (TO to)
#                 (VP
#                   (VB have)
#                   (S
#                     (NP-SBJ (-NONE- *-2))
#                     (VP
#                       (TO to)
#                       (VP
#                         (VB swing)
#                         (ADVP-DIR (RB back))
#                         (NP-DIR (DT the) (JJ other) (NN way))
#                         (, ,)
#                         (SBAR-PRP
#                           (IN because)
#                           (S
#                             (NP-SBJ (PRP I))
#                             (VP
#                               (VBP think)
#                               (SBAR
#                                 (-NONE- 0)
#                                 (S
#                                   (NP-SBJ-3 (PRP we))
#                                   (VP
#                                     (VBP 're)
#                                     (VP
#                                       (VBG going)
#                                       (S
#                                         (NP-SBJ (-NONE- *-3))
#                                         (VP
#                                           (TO to)
#                                           (VP
#                                             (VB have)
#                                             (NP
#                                               (NP
#                                                 (DT an)
#                                                 (JJ awful)
#                                                 (NN lot))
#                                               (PP
#                                                 (IN of)
#                                                 (NP (NNS kids)))
#                                               (SBAR
#                                                 (WHNP-4 (WP who))
#                                                 (S
#                                                   (NP-SBJ-5
#                                                     (-NONE- *T*-4))
#                                                   (VP
#                                                     (VBP are)
#                                                     (VP
#                                                       (VBG going)
#                                                       (S
#                                                         (NP-SBJ
#                                                           (-NONE-
#                                                             *-5))
#                                                         (VP
#                                                           (TO to)
#                                                           (VP
#                                                             (VB have)
#                                                             (NP
#                                                               (NP
#                                                                 (JJ
#                                                                   major)
#                                                                 (NNS
#                                                                   problems))
#                                                               (PP
#                                                                 (IN
#                                                                   from)
#                                                                 (NP
#                                                                   (PDT
#                                                                     all)
#                                                                   (DT
#                                                                     this)))))))))))))))))))))))))))))))))
#   (. .)
#   (-DFL- E_S))
# Least complex trees by normalized depth:
#
# 1.(from conv. no. 2836) (S  and  ,  uh  ,  you  know  ,  two  counts  of  kidnapping  ,  uh  you  know  ,  \[  the  ,  \+  the  \]  forty-five  to  the  head  ,  you  know  ,  just  \[  the  ,  \+  the  \]  mental  anguish  and  the  whole  nine  yards  uh  ,  you  know  ,  the  guy  only  got  five  years  .  E_S)
#  (S
#   (CC and)
#   (, ,)
#   (INTJ (UH uh))
#   (PRN (, ,) (S (NP-SBJ (PRP you)) (VP (VBP know))) (, ,))
#   (NP-ADV
#     (NP (NP (CD two) (NNS counts)) (PP (IN of) (NP (NN kidnapping))))
#     (, ,)
#     (INTJ (UH uh))
#     (PRN (S (NP-SBJ (PRP you)) (VP (VBP know))) (, ,))
#     (EDITED (RM (-DFL- \[)) (NP-UNF (DT the)) (, ,) (IP (-DFL- \+)))
#     (NP
#       (NP (DT the) (RS (-DFL- \])) (CD forty-five))
#       (PP-LOC (IN to) (NP (DT the) (NN head))))
#     (PRN (, ,) (S (NP-SBJ (PRP you)) (VP (VBP know))) (, ,))
#     (ADVP (RB just))
#     (EDITED (RM (-DFL- \[)) (NP-UNF (DT the)) (, ,) (IP (-DFL- \+)))
#     (NP (DT the) (RS (-DFL- \])) (JJ mental) (NN anguish))
#     (CC and)
#     (NP (DT the) (JJ whole) (CD nine) (NNS yards)))
#   (INTJ (UH uh))
#   (PRN (, ,) (S (NP-SBJ (PRP you)) (VP (VBP know))) (, ,))
#   (NP-SBJ (DT the) (NN guy))
#   (ADVP (RB only))
#   (VP (VBD got) (NP (CD five) (NNS years)))
#   (. .)
#   (-DFL- E_S))
# 2.(from conv. no. 2969) (NP G o m p h r e n a . E_S)
#  (NP
#   (SYM G)
#   (SYM o)
#   (SYM m)
#   (SYM p)
#   (SYM h)
#   (SYM r)
#   (SYM e)
#   (SYM n)
#   (SYM a)
#   (. .)
#   (-DFL- E_S))
# 3.(from conv. no. 3393) (S  and  then  uh  ,  into  of  November  ,  \[  \[  the  first  ,  \+  like  the  second  \]  week  ,  \+  uh  ,  you  know  ,  the  first  week  \]  actually  ,  \[  we  had  ,  \+  we  had  \]  a  freeze  ,  E_S)
#  (S
#   (CONJP (CC and) (RB then))
#   (INTJ (UH uh))
#   (, ,)
#   (PP-TMP (IN into) (X (PP-UNF (IN of))) (NP (NNP November)))
#   (, ,)
#   (EDITED
#     (RM (-DFL- \[))
#     (EDITED
#       (RM (-DFL- \[))
#       (NP-TMP-UNF (DT the) (JJ first))
#       (, ,)
#       (IP (-DFL- \+)))
#     (INTJ (UH like))
#     (NP-TMP (DT the) (JJ second) (RS (-DFL- \])) (NN week))
#     (, ,)
#     (IP (-DFL- \+)))
#   (INTJ (UH uh))
#   (PRN (, ,) (S (NP-SBJ (PRP you)) (VP (VBP know))) (, ,))
#   (NP-TMP (DT the) (JJ first) (NN week))
#   (RS (-DFL- \]))
#   (ADVP (UH actually))
#   (, ,)
#   (EDITED
#     (RM (-DFL- \[))
#     (S (NP-SBJ (PRP we)) (VP-UNF (VBD had)))
#     (, ,)
#     (IP (-DFL- \+)))
#   (NP-SBJ (PRP we))
#   (VP (VBD had) (RS (-DFL- \])) (NP (DT a) (NN freeze)))
#   (, ,)
#   (-DFL- E_S))
# 4.(from conv. no. 2472) (NP  Sliced  tomatoes  and  then  green  pepper  strips  ,  just  over  it  ,  and  some  red  onion  slices  ,  and  just  a  little  bit  of  ,  um  ,  basil  ,  and  then  a  little  Italian  dressing  over  it  .  E_S)
#  (NP
#   (NP (JJ Sliced) (NNS tomatoes))
#   (CONJP (CC and) (RB then))
#   (NP
#     (NP (JJ green) (NN pepper) (NNS strips))
#     (, ,)
#     (PP-LOC (ADVP (RB just)) (IN over) (NP (PRP it))))
#   (, ,)
#   (CC and)
#   (NP (DT some) (JJ red) (NN onion) (NNS slices))
#   (, ,)
#   (CC and)
#   (NP
#     (NP (RB just) (DT a) (JJ little) (NN bit))
#     (PP (IN of) (, ,) (INTJ (UH um)) (, ,) (NP (NN basil))))
#   (, ,)
#   (CONJP (CC and) (RB then))
#   (NP
#     (NP (NP-ADV (DT a) (JJ little)) (JJ Italian) (NN dressing))
#     (PP-LOC (IN over) (NP (PRP it))))
#   (. .)
#   (-DFL- E_S))
# 5.(from conv. no. 2304) (FRAG  \[  Actually  ,  \+  actually  \]  a  little  bit  later  ,  like  \[  \[  nineteen  thirteen  ,  \+  nineteen  twelve  ,  \]  \+  nineteen  thirteen  .  \]  E_S)
#  (FRAG
#   (EDITED (RM (-DFL- \[)) (ADVP (RB Actually)) (, ,) (IP (-DFL- \+)))
#   (ADVP (RB actually))
#   (RS (-DFL- \]))
#   (ADVP-TMP (NP (DT a) (JJ little) (NN bit)) (RB later))
#   (, ,)
#   (INTJ (UH like))
#   (RM (-DFL- \[))
#   (EDITED
#     (RM (-DFL- \[))
#     (NP (CD nineteen) (CD thirteen))
#     (, ,)
#     (IP (-DFL- \+)))
#   (NP
#     (NP (CD nineteen) (CD twelve))
#     (, ,)
#     (RS (-DFL- \]))
#     (IP (-DFL- \+))
#     (NP (CD nineteen) (CD thirteen)))
#   (. .)
#   (RS (-DFL- \]))
#   (-DFL- E_S))
# 6.(from conv. no. 2051) (ADVP North , south , east , or west ? E_S)
#  (ADVP
#   (RB North)
#   (, ,)
#   (RB south)
#   (, ,)
#   (RB east)
#   (, ,)
#   (CC or)
#   (RB west)
#   (. ?)
#   (-DFL- E_S))
# 7.(from conv. no. 4765) (S  \[  \[  and  \+  and  so  ,  \]  \+  uh  ,  \[  but  ,  \+  but  ,  \]  \]  sometimes  ,  you  know  ,  drug  use  \[  can  ,  \+  can  \]  escape  that  .  E_S)
#  (S
#   (EDITED
#     (RM (-DFL- \[))
#     (EDITED (RM (-DFL- \[)) (CC and) (IP (-DFL- \+)))
#     (CONJP (CC and) (RB so))
#     (, ,)
#     (RS (-DFL- \]))
#     (IP (-DFL- \+)))
#   (INTJ (UH uh))
#   (, ,)
#   (EDITED (RM (-DFL- \[)) (CC but) (, ,) (IP (-DFL- \+)))
#   (CC but)
#   (, ,)
#   (RS (-DFL- \]))
#   (RS (-DFL- \]))
#   (NP-TMP (RB sometimes))
#   (PRN (, ,) (S (NP-SBJ (PRP you)) (VP (VBP know))) (, ,))
#   (NP-SBJ (NN drug) (NN use))
#   (EDITED (RM (-DFL- \[)) (VP-UNF (MD can) (, ,)) (IP (-DFL- \+)))
#   (VP (MD can) (RS (-DFL- \])) (VP (VB escape) (NP (DT that))))
#   (. .)
#   (-DFL- E_S))
# 8.(from conv. no. 3393) (S  But  all  of  a  sudden  ,  \[  \[  in  ,  \+  in  ,  \]  \+  uh  ,  in  \]  \[  \[  October  ,  \+  uh  ,  September  ,  \]  \+  October  \]  it  got  real  hot  and  dry  and  just  stayed  that  way  for  a  long  time  .  E_S)
#  (S
#   (CC But)
#   (NP-TMP (NP (DT all)) (PP (IN of) (NP (DT a) (NN sudden))))
#   (, ,)
#   (EDITED
#     (RM (-DFL- \[))
#     (EDITED
#       (RM (-DFL- \[))
#       (PP-TMP-UNF (IN in))
#       (, ,)
#       (IP (-DFL- \+)))
#     (PP-TMP-UNF (IN in))
#     (, ,)
#     (RS (-DFL- \]))
#     (IP (-DFL- \+)))
#   (INTJ (UH uh))
#   (, ,)
#   (PP-TMP
#     (IN in)
#     (RS (-DFL- \]))
#     (EDITED
#       (RM (-DFL- \[))
#       (EDITED
#         (RM (-DFL- \[))
#         (NP (NNP October))
#         (, ,)
#         (IP (-DFL- \+)))
#       (INTJ (UH uh))
#       (, ,)
#       (NP (NNP September))
#       (, ,)
#       (RS (-DFL- \]))
#       (IP (-DFL- \+)))
#     (NP (NNP October)))
#   (RS (-DFL- \]))
#   (NP-SBJ (PRP it))
#   (VP
#     (VP (VBD got) (ADJP-PRD (RB real) (JJ hot) (CC and) (JJ dry)))
#     (CC and)
#     (VP
#       (ADVP (RB just))
#       (VBD stayed)
#       (NP-MNR (DT that) (NN way))
#       (PP-TMP (IN for) (NP (DT a) (JJ long) (NN time)))))
#   (. .)
#   (-DFL- E_S))
# 9.(from conv. no. 3068) (NP  a  big  science  school  ,  no  football  team  ,  but  a  big  science  school  ,  E_S)
#  (NP
#   (NP (DT a) (JJ big) (NN science) (NN school))
#   (, ,)
#   (NP (DT no) (NN football) (NN team))
#   (, ,)
#   (CC but)
#   (NP (DT a) (JJ big) (NN science) (NN school))
#   (, ,)
#   (-DFL- E_S))
# 10.(from conv. no. 2331) (S  and  ,  uh  um  ,  \[  the  ,  \+  the  \]  last  time  \[  I  ,  \+  I  \]  took  my  wife  along  E_S)
#  (S
#   (CC and)
#   (, ,)
#   (INTJ (UH uh))
#   (INTJ (UH um))
#   (, ,)
#   (EDITED
#     (RM (-DFL- \[))
#     (NP-TMP-UNF (DT the))
#     (, ,)
#     (IP (-DFL- \+)))
#   (NP-TMP (DT the) (RS (-DFL- \])) (JJ last) (NN time))
#   (EDITED (RM (-DFL- \[)) (NP-SBJ (PRP I)) (, ,) (IP (-DFL- \+)))
#   (NP-SBJ (PRP I))
#   (RS (-DFL- \]))
#   (VP (VBD took) (NP (PRP$ my) (NN wife)) (ADVP (IN along)))
#   (-DFL- E_S))
#
#
# Most complex trees by normalized depth*width:
#
# 1.(from conv. no. 4123) (S  if  you  watch  the  news  ,  \[  you  're  going  ,  \+  your  opinion  is  going  \]  *-1  to  be  formed  *-2  \[  about  ,  \+  \]  on  what  somebody  else  thought  *T*-3  about  it  as  opposed  to  *  actually  watching  it  yourself  and  forming  your  own  \[  pinion  ,  \+  opinion  ,  \]  which  I  \[  have  n't  ,  \+  would  \]  be  much  more  in  favor  of  *T*-4  *  forming  my  own  opinion  as  opposed  to  *  following  someone  else  's  .  E_S)
#  (S
#   (SBAR-ADV
#     (IN if)
#     (S (NP-SBJ (PRP you)) (VP (VBP watch) (NP (DT the) (NN news)))))
#   (, ,)
#   (EDITED
#     (RM (-DFL- \[))
#     (S (NP-SBJ (PRP you)) (VP (VBP 're) (VP-UNF (VBG going))))
#     (, ,)
#     (IP (-DFL- \+)))
#   (NP-SBJ-1 (PRP$ your) (NN opinion))
#   (VP
#     (VBZ is)
#     (VP
#       (VBG going)
#       (RS (-DFL- \]))
#       (S
#         (NP-SBJ-2 (-NONE- *-1))
#         (VP
#           (TO to)
#           (VP
#             (VB be)
#             (VP
#               (VBN formed)
#               (NP (-NONE- *-2))
#               (EDITED
#                 (RM (-DFL- \[))
#                 (PP-UNF (IN about))
#                 (, ,)
#                 (IP (-DFL- \+))
#                 (RS (-DFL- \])))
#               (PP
#                 (IN on)
#                 (SBAR-NOM
#                   (SBAR-NOM
#                     (WHNP-3 (WP what))
#                     (S
#                       (NP-SBJ (NP (NN somebody)) (ADVP (RB else)))
#                       (VP
#                         (VBD thought)
#                         (NP (-NONE- *T*-3))
#                         (PP (IN about) (NP (PRP it))))))
#                   (PP
#                     (IN as)
#                     (PP
#                       (VBN opposed)
#                       (PP
#                         (IN to)
#                         (S-NOM
#                           (NP-SBJ (-NONE- *))
#                           (VP
#                             (VP
#                               (VP
#                                 (ADVP (RB actually))
#                                 (VBG watching)
#                                 (NP (PRP it))
#                                 (NP-ADV (PRP yourself)))
#                               (CC and)
#                               (VP
#                                 (VBG forming)
#                                 (NP
#                                   (PRP$ your)
#                                   (JJ own)
#                                   (EDITED
#                                     (RM (-DFL- \[))
#                                     (NN pinion)
#                                     (, ,)
#                                     (IP (-DFL- \+)))
#                                   (NN opinion))))
#                             (, ,)
#                             (RS (-DFL- \]))
#                             (SBAR
#                               (WHNP-4 (WDT which))
#                               (S
#                                 (NP-SBJ (PRP I))
#                                 (EDITED
#                                   (RM (-DFL- \[))
#                                   (VP-UNF (VBP have) (RB n't))
#                                   (, ,)
#                                   (IP (-DFL- \+)))
#                                 (VP
#                                   (MD would)
#                                   (RS (-DFL- \]))
#                                   (VP
#                                     (VB be)
#                                     (PP-PRD
#                                       (ADVP (RB much) (RBR more))
#                                       (IN in)
#                                       (NP
#                                         (NP (NN favor))
#                                         (PP
#                                           (IN of)
#                                           (NP
#                                             (NP
#                                               (NP (-NONE- *T*-4))
#                                               (S-NOM
#                                                 (NP-SBJ (-NONE- *))
#                                                 (VP
#                                                   (VBG forming)
#                                                   (NP
#                                                     (PRP$ my)
#                                                     (JJ own)
#                                                     (NN opinion)))))
#                                             (PP
#                                               (IN as)
#                                               (PP
#                                                 (VBN opposed)
#                                                 (PP
#                                                   (IN to)
#                                                   (S-NOM
#                                                     (NP-SBJ
#                                                       (-NONE- *))
#                                                     (VP
#                                                       (VBG following)
#                                                       (NP
#                                                         (NP
#                                                           (NN
#                                                             someone))
#                                                         (ADVP
#                                                           (RB else))
#                                                         (POS 's))))))))))))))))))))))))))))
#   (. .)
#   (-DFL- E_S))
# 2.(from conv. no. 3074) (S  \[  I  ,  \+  I  \]  wonder  \[  how  ,  \+  how  \]  you  instill  in  people  the  necessity  for  *  doing  just  a  little  bit  extra  *  \[  to  ,  \+  to  \]  make  this  whole  thing  work  .  I  mean  ,  *  the  extra  like  washing  out  bottles  and  jars  ,  or  the  extra  of  actually  ,  uh  ,  *  making  *  sure  that  ,  uh  ,  you  take  stuff  over  to  ,  you  know  *T*-1  ,  N_S)
#  (S
#   (EDITED (RM (-DFL- \[)) (NP-SBJ (PRP I)) (, ,) (IP (-DFL- \+)))
#   (NP-SBJ (PRP I))
#   (RS (-DFL- \]))
#   (VP
#     (VBP wonder)
#     (SBAR
#       (EDITED
#         (RM (-DFL- \[))
#         (WHADVP (WRB how))
#         (, ,)
#         (IP (-DFL- \+)))
#       (WHADVP-1 (WRB how))
#       (RS (-DFL- \]))
#       (S
#         (NP-SBJ (PRP you))
#         (VP
#           (VBP instill)
#           (PP (IN in) (NP (NNS people)))
#           (NP
#             (NP (DT the) (NN necessity))
#             (PP
#               (IN for)
#               (S-NOM
#                 (NP-SBJ (-NONE- *))
#                 (VP
#                   (VBG doing)
#                   (NP
#                     (NP-ADV (RB just) (DT a) (JJ little) (NN bit))
#                     (JJ extra))
#                   (S-PRP
#                     (NP-SBJ (-NONE- *))
#                     (EDITED
#                       (RM (-DFL- \[))
#                       (VP-UNF (TO to))
#                       (, ,)
#                       (IP (-DFL- \+)))
#                     (VP
#                       (TO to)
#                       (RS (-DFL- \]))
#                       (VP
#                         (VB make)
#                         (S
#                           (NP-SBJ (DT this) (JJ whole) (NN thing))
#                           (VP
#                             (VB work)
#                             (PRN
#                               (. .)
#                               (S (NP-SBJ (PRP I)) (VP (VBP mean)))
#                               (, ,))
#                             (NP
#                               (S-NOM
#                                 (NP-SBJ (-NONE- *))
#                                 (VP
#                                   (DT the)
#                                   (JJ extra)
#                                   (INTJ (UH like))
#                                   (VBG washing)
#                                   (PRT (RP out))
#                                   (NP
#                                     (NNS bottles)
#                                     (CC and)
#                                     (NNS jars))))
#                               (, ,)
#                               (CC or)
#                               (NP
#                                 (NP (DT the) (JJ extra))
#                                 (PP
#                                   (IN of)
#                                   (ADVP (RB actually))
#                                   (, ,)
#                                   (INTJ (UH uh))
#                                   (, ,)
#                                   (S-NOM
#                                     (NP-SBJ (-NONE- *))
#                                     (VP
#                                       (VBG making)
#                                       (S
#                                         (NP-SBJ (-NONE- *))
#                                         (ADJP-PRD
#                                           (JJ sure)
#                                           (SBAR
#                                             (IN that)
#                                             (, ,)
#                                             (INTJ (UH uh))
#                                             (, ,)
#                                             (S
#                                               (NP-SBJ (PRP you))
#                                               (VP
#                                                 (VBP take)
#                                                 (NP (NN stuff))
#                                                 (PP-DIR
#                                                   (IN over)
#                                                   (PP-UNF
#                                                     (TO to)
#                                                     (PRN
#                                                       (, ,)
#                                                       (S
#                                                         (NP-SBJ
#                                                           (PRP you))
#                                                         (VP
#                                                           (VBP know)))))))))))))))))))))))))
#           (ADVP-MNR (-NONE- *T*-1))))))
#   (, ,)
#   (-DFL- N_S))
# 3.(from conv. no. 4082) (S  I  know  of  cases  where  ,  uh  ,  we  have  one  television  media  where  they  will  show  clippings  from  one  event  and  describe  another  event  but  ,  with  \[  the  \+  the  \]  attempt  *  to  give  you  the  impression  that  what  they  're  talking  about  *T*-1  is  the  same  thing  0  they  are  showing  you  *T*-2  .  Which  *T*-4  is  sort  of  like  a  deliberate  bias  *T*-5  .  \[  Which  *T*-7  is  \+  which  *T*-3  is  \]  rather  disturbing  *T*-6  .  E_S)
#  (S
#   (NP-SBJ (PRP I))
#   (VP
#     (VBP know)
#     (PP
#       (IN of)
#       (NP
#         (NP (NNS cases))
#         (SBAR
#           (WHADVP-6 (WRB where))
#           (, ,)
#           (INTJ (UH uh))
#           (, ,)
#           (S
#             (NP-SBJ (PRP we))
#             (VP
#               (VBP have)
#               (NP
#                 (NP (CD one) (NN television) (NN media))
#                 (SBAR
#                   (WHADVP-5 (WRB where))
#                   (S
#                     (NP-SBJ (PRP they))
#                     (VP
#                       (MD will)
#                       (VP
#                         (VP
#                           (VP
#                             (VB show)
#                             (NP
#                               (NP (NNS clippings))
#                               (PP (IN from) (NP (CD one) (NN event)))))
#                           (CC and)
#                           (VP
#                             (VB describe)
#                             (NP (DT another) (NN event)))
#                           (NAC
#                             (CC but)
#                             (, ,)
#                             (PP
#                               (IN with)
#                               (EDITED
#                                 (RM (-DFL- \[))
#                                 (NP-UNF (DT the))
#                                 (IP (-DFL- \+)))
#                               (NP
#                                 (NP
#                                   (DT the)
#                                   (RS (-DFL- \]))
#                                   (NN attempt)
#                                   (S
#                                     (NP-SBJ (-NONE- *))
#                                     (VP
#                                       (TO to)
#                                       (VP
#                                         (VB give)
#                                         (NP (PRP you))
#                                         (NP
#                                           (DT the)
#                                           (NN impression)
#                                           (SBAR
#                                             (IN that)
#                                             (S
#                                               (SBAR-NOM-SBJ
#                                                 (WHNP-1 (WP what))
#                                                 (S
# ...
#           (, ,)
#           (NP
#             (NN respect)
#             (SBAR
#               (IN that)
#               (PRN
#                 (, ,)
#                 (S (NP-SBJ (PRP you)) (VP (VBP know)))
#                 (, ,))
#               (S
#                 (NP-SBJ (EX there))
#                 (VP
#                   (BES 's)
#                   (NP-PRD
#                     (NP (JJ endless) (NNS amounts))
#                     (PP
#                       (IN of)
#                       (NP
#                         (NP (NN research))
#                         (SBAR
#                           (WHNP-2 (-NONE- 0))
#                           (S
#                             (NP-SBJ-3 (-NONE- *T*-2))
#                             (VP
#                               (TO to)
#                               (VP
#                                 (VB be)
#                                 (VP (VBN done) (NP (-NONE- *-3)))))))))
#                     (. .)
#                     (NP
#                       (NP (JJ Endless) (NNS amounts))
#                       (PP
#                         (IN of)
#                         (NP
#                           (NNS resources)
#                           (EDITED
#                             (RM (-DFL- \[))
#                             (CC and)
#                             (IP (-DFL- \+)))
#                           (CC and)
#                           (RS (-DFL- \]))
#                           (NN whatnot)))))))))))))
#   (, ,)
#   (-DFL- E_S))
# 8.(from conv. no. 2259) (S  \[  And  ,  \+  uh  ,  so  \]  I  think  ,  uh  ,  you  know  ,  0  the  ,  uh  ,  embargo  0  we  placed  *T*-1  \[  on  the  ,  \+  uh  ,  on  the  \]  Russian  Jews  ,  although  we  MUMBLEx  \[  of  ,  \+  \]  uh  ,  spent  years  and  years  ,  uh  ,  *-5  lobbying  for  their  release  and  their  ability  *  to  ,  um  ,  immigrate  from  Russia  as  soon  as  that  occurred  ,  we  simply  said  that  ,  uh  ,  instead  of  the  ,  uh  ,  hundred  and  fifty  thousand  or  so  who  *T*-2  wanted  *-3  to  immigrate  to  this  country  ,  we  cut  that  by  ,  uh  ,  two  thirds  .  E_S)
#  (S
#   (EDITED (RM (-DFL- \[)) (CC And) (, ,) (IP (-DFL- \+)))
#   (INTJ (UH uh))
#   (, ,)
#   (RB so)
#   (RS (-DFL- \]))
#   (NP-SBJ (PRP I))
#   (VP
#     (VBP think)
#     (, ,)
#     (INTJ (UH uh))
#     (PRN (, ,) (S (NP-SBJ (PRP you)) (VP (VBP know))) (, ,))
#     (SBAR
#       (-NONE- 0)
#       (S
#         (NP-ADV
#           (NP (DT the) (, ,) (INTJ (UH uh)) (, ,) (NN embargo))
#           (SBAR
#             (WHNP-1 (-NONE- 0))
#             (S
#               (NP-SBJ (PRP we))
#               (VP
#                 (VBD placed)
#                 (NP (-NONE- *T*-1))
#                 (EDITED
#                   (RM (-DFL- \[))
#                   (PP (IN on) (NP-UNF (DT the)))
#                   (, ,)
#                   (IP (-DFL- \+)))
#                 (INTJ (UH uh))
#                 (, ,)
#                 (PP
#                   (IN on)
#                   (NP
#                     (DT the)
#                     (RS (-DFL- \]))
#                     (JJ Russian)
#                     (NNPS Jews)))))))
#         (, ,)
#         (SBAR-ADV
#           (IN although)
#           (S
#             (NP-SBJ-5 (PRP we))
#             (X (XX MUMBLEx))
#             (EDITED
#               (RM (-DFL- \[))
#               (PP-UNF (IN of))
#               (, ,)
#               (IP (-DFL- \+)))
#             (RS (-DFL- \]))
#             (INTJ (UH uh))
#             (, ,)
#             (VP
#               (VBD spent)
#               (NP (NNS years) (CC and) (NNS years))
#               (, ,)
#               (INTJ (UH uh))
#               (, ,)
#               (S-ADV
#                 (NP-SBJ (-NONE- *-5))
#                 (VP
#                   (VBG lobbying)
#                   (PP
#                     (IN for)
#                     (NP
#                       (NP (PRP$ their) (NN release))
#                       (CC and)
#                       (NP
#                         (PRP$ their)
#                         (NN ability)
#                         (S
#                           (NP-SBJ (-NONE- *))
#                           (VP
#                             (TO to)
#                             (, ,)
#                             (INTJ (UH um))
#                             (, ,)
#                             (VP
#                               (VB immigrate)
#                               (PP-DIR (IN from) (NP (NNP Russia))))))))))))))
#         (ADVP-TMP
#           (ADVP (RB as) (RB soon))
#           (SBAR (IN as) (S (NP-SBJ (DT that)) (VP (VBN occurred)))))
#         (, ,)
#         (NP-SBJ (PRP we))
#         (ADVP (RB simply))
#         (VP
#           (VBD said)
#           (SBAR
#             (IN that)
#             (, ,)
#             (INTJ (UH uh))
#             (, ,)
#             (S
#               (PP
#                 (IN instead)
#                 (IN of)
#                 (NP
#                   (NP
#                     (DT the)
#                     (, ,)
#                     (INTJ (UH uh))
#                     (, ,)
#                     (QP
#                       (CD hundred)
#                       (CC and)
#                       (CD fifty)
#                       (CD thousand)
#                       (CC or)
#                       (RB so)))
#                   (SBAR
#                     (WHNP-2 (WP who))
#                     (S
#                       (NP-SBJ-3 (-NONE- *T*-2))
#                       (VP
#                         (VBD wanted)
#                         (S
#                           (NP-SBJ (-NONE- *-3))
#                           (VP
#                             (TO to)
#                             (VP
#                               (VB immigrate)
#                               (PP-DIR
#                                 (IN to)
#                                 (NP (DT this) (NN country)))))))))))
#               (, ,)
#               (NP-SBJ (PRP we))
#               (VP
#                 (VBP cut)
#                 (NP (DT that))
#                 (PP
#                   (IN by)
#                   (, ,)
#                   (INTJ (UH uh))
#                   (, ,)
#                   (NP (CD two) (NNS thirds))))))))))
#   (. .)
#   (-DFL- E_S))
# 9.(from conv. no. 4765) (S  And  ,  uh  ,  I  have  absolutely  no  compunction  about  ,  uh  ,  *  using  any  and  all  means  *  \[  to  ,  \+  to  ,  \]  uh  ,  uh  ,  you  know  ,  \[  work  out  ,  \+  figure  out  \]  \[  who  *T*-3  has  a  drug  program  \+  or  who  *T*-1  has  a  drug  problem  \]  \[  and  ,  \+  uh  ,  and  \]  putting  that  guy  \[  into  ,  \+  into  \]  therapy  \[  \[  to  ,  \+  whatever  it  is  *T*-2  *  to  ,  \]  \+  to  ,  \]  you  know  ,  break  this  ,  uh  ,  activity  .  E_S)
#  (S
#   (CC And)
#   (, ,)
#   (INTJ (UH uh))
#   (, ,)
#   (NP-SBJ (PRP I))
#   (VP
#     (VBP have)
#     (ADVP (RB absolutely))
#     (NP
#       (NP (DT no) (NN compunction))
#       (PP
#         (IN about)
#         (, ,)
#         (INTJ (UH uh))
#         (, ,)
#         (S-NOM
#           (NP-SBJ (-NONE- *))
#           (VP
#             (VBG using)
#             (NP (DT any) (CC and) (DT all) (NNS means))
#             (S-PRP
#               (NP-SBJ (-NONE- *))
#               (EDITED
#                 (RM (-DFL- \[))
#                 (VP-UNF (TO to))
#                 (, ,)
#                 (IP (-DFL- \+)))
#               (VP
#                 (TO to)
#                 (, ,)
#                 (RS (-DFL- \]))
#                 (INTJ (UH uh))
#                 (, ,)
#                 (INTJ (UH uh))
#                 (PRN
#                   (, ,)
#                   (S (NP-SBJ (PRP you)) (VP (VBP know)))
#                   (, ,))
#                 (EDITED
#                   (RM (-DFL- \[))
#                   (VP-UNF (VB work) (PRT (RP out)))
#                   (, ,)
#                   (IP (-DFL- \+)))
#                 (VP
#                   (VP
#                     (VB figure)
#                     (PRT (RP out))
#                     (RS (-DFL- \]))
#                     (EDITED
#                       (RM (-DFL- \[))
#                       (SBAR
#                         (WHNP-3 (WP who))
#                         (S
#                           (NP-SBJ (-NONE- *T*-3))
#                           (VP
#                             (VBZ has)
#                             (NP-PRD (DT a) (NN drug) (NN program)))))
#                       (IP (-DFL- \+))
#                       (CC or))
#                     (SBAR-NOM
#                       (WHNP-1 (WP who))
#                       (S
#                         (NP-SBJ (-NONE- *T*-1))
#                         (VP
#                           (VBZ has)
#                           (NP (DT a) (NN drug) (NN problem)))))
#                     (RS (-DFL- \])))
#                   (EDITED
#                     (RM (-DFL- \[))
#                     (CC and)
#                     (, ,)
#                     (IP (-DFL- \+)))
#                   (INTJ (UH uh))
#                   (, ,)
#                   (CC and)
#                   (RS (-DFL- \]))
#                   (VP
#                     (VBG putting)
#                     (NP (DT that) (NN guy))
#                     (EDITED
#                       (RM (-DFL- \[))
#                       (PP-PUT-UNF (IN into))
#                       (, ,)
#                       (IP (-DFL- \+)))
#                     (PP-PUT
#                       (IN into)
#                       (RS (-DFL- \]))
#                       (NP
#                         (NP (NN therapy))
#                         (EDITED
#                           (RM (-DFL- \[))
#                           (EDITED
#                             (RM (-DFL- \[))
#                             (VP-UNF (TO to))
#                             (, ,)
#                             (IP (-DFL- \+))))
#                         (SBAR-NOM
#                           (WHNP-2 (WDT whatever))
#                           (S
#                             (NP-SBJ (PRP it))
#                             (VP (VBZ is) (NP (-NONE- *T*-2))))))
#                       (S-PRP
#                         (NP-SBJ (-NONE- *))
#                         (EDITED
#                           (VP-UNF (TO to))
#                           (, ,)
#                           (RS (-DFL- \]))
#                           (IP (-DFL- \+)))
#                         (VP
#                           (TO to)
#                           (, ,)
#                           (RS (-DFL- \]))
#                           (PRN
#                             (S (NP-SBJ (PRP you)) (VP (VBP know)))
#                             (, ,))
#                           (VP
#                             (VB break)
#                             (NP
#                               (DT this)
#                               (, ,)
#                               (INTJ (UH uh))
#                               (, ,)
#                               (NP (NN activity))))))))))))))))
#   (. .)
#   (-DFL- E_S))
# 10.(from conv. no. 3268) (S  Uh  ,  \[  my  ,  \+  my  \]  idea  I  guess  of  the  ideal  vacation  would  be  0  *  to  begin  with  ,  uh  ,  money  be  no  object  .  You  know  ,  so  just  absolutely  ,  you  know  ,  first  class  *  fly  where  I  want  *-1  to  *?*  *T*-2  ,  rent  a  car  if  I  want  *-3  to  *?*  .  Uh  ,  you  know  ,  just  \[  the  ,  \+  really  the  \]  nicest  hotels  and  stuff  like  that  \[  and  \+  and  \]  not  worry  if  somebody  says  ,  well  ,  *  let  's  take  this  little  side  trip  ,  you  know  ,  and  not  have  *  to  sit  there  and  figure  out  ,  um  ,  you  know  ,  again  \[  we  ,  \+  we  \]  fit  that  in  there  or  not  .  E_S)
#  (S
#   (INTJ (UH Uh))
#   (, ,)
#   (EDITED
#     (RM (-DFL- \[))
#     (NP-SBJ-UNF (PRP$ my))
#     (, ,)
#     (IP (-DFL- \+)))
#   (NP-SBJ
#     (NP (PRP$ my) (RS (-DFL- \])) (NN idea))
#     (PRN (S (NP-SBJ (PRP I)) (VP (VBP guess))))
#     (PP (IN of) (NP (DT the) (JJ ideal) (NN vacation))))
#   (VP
#     (MD would)
#     (VP
#       (VB be)
#       (SBAR-PRD
#         (-NONE- 0)
#         (S
#           (S-ADV
#             (NP-SBJ (-NONE- *))
#             (VP (TO to) (VP (VB begin) (ADVP (IN with)))))
#           (, ,)
#           (INTJ (UH uh))
#           (, ,)
#           (S-ADV
#             (NP-SBJ (NN money))
#             (VP (VB be) (NP-PRD (DT no) (NN object))))
#           (PRN (. .) (S (NP-SBJ (PRP You)) (VP (VBP know))) (, ,))
#           (S-PRD
#             (ADVP (RB so))
#             (ADVP (RB just))
#             (ADVP
#               (RB absolutely)
#               (PRN
#                 (, ,)
#                 (S (NP-SBJ (PRP you)) (VP (VBP know)))
#                 (, ,))
#               (JJ first)
#               (NN class)))
#           (NP-SBJ (-NONE- *))
#           (VP
#             (VP
#               (VB fly)
#               (SBAR-DIR
#                 (WHADVP-2 (WRB where))
#                 (S
#                   (NP-SBJ-1 (PRP I))
#                   (VP
#                     (VBP want)
#                     (S
#                       (NP-SBJ (-NONE- *-1))
#                       (VP
#                         (TO to)
#                         (VP (-NONE- *?*) (ADVP-DIR (-NONE- *T*-2)))))))))
#             (, ,)
#             (VP
#               (VB rent)
#               (NP (DT a) (NN car))
#               (SBAR-ADV
#                 (IN if)
#                 (S
#                   (NP-SBJ-3 (PRP I))
#                   (VP
#                     (VB want)
#                     (S
#                       (NP-SBJ (-NONE- *-3))
#                       (VP (TO to) (VP (-NONE- *?*))))))))
#             (PRN
#               (. .)
#               (FRAG
#                 (INTJ (UH Uh))
#                 (PRN
#                   (, ,)
#                   (S (NP-SBJ (PRP you)) (VP (VBP know)))
#                   (, ,))
#                 (ADVP (RB just))
#                 (EDITED
#                   (RM (-DFL- \[))
#                   (NP-UNF (DT the))
#                   (, ,)
#                   (IP (-DFL- \+)))
#                 (ADVP (RB really))
#                 (NP
#                   (NP
#                     (DT the)
#                     (RS (-DFL- \]))
#                     (JJS nicest)
#                     (NNS hotels))
#                   (CC and)
#                   (NP (NP (NN stuff)) (PP (IN like) (NP (DT that)))))))
#             (EDITED (RM (-DFL- \[)) (CC and) (IP (-DFL- \+)))
#             (CC and)
#             (RS (-DFL- \]))
#             (VP
#               (RB not)
#               (VB worry)
#               (SBAR-ADV
#                 (IN if)
#                 (S
#                   (NP-SBJ (NN somebody))
#                   (VP
#                     (VBZ says)
#                     (, ,)
#                     (S-IMP
#                       (INTJ (UH well))
#                       (, ,)
#                       (NP-SBJ (-NONE- *))
#                       (VP
#                         (VB let)
#                         (S
#                           (NP-SBJ (PRP 's))
#                           (VP
#                             (VB take)
#                             (NP
#                               (DT this)
#                               (JJ little)
#                               (NN side)
#                               (NN trip))))))))))
#             (PRN (, ,) (S (NP-SBJ (PRP you)) (VP (VBP know))) (, ,))
#             (CC and)
#             (VP
#               (RB not)
#               (VB have)
#               (S
#                 (NP-SBJ (-NONE- *))
#                 (VP
#                   (TO to)
#                   (VP
#                     (VP (VB sit) (ADVP-LOC (RB there)))
#                     (CC and)
#                     (VP
#                       (VB figure)
#                       (PRT (RP out))
#                       (, ,)
#                       (INTJ (UH um))
#                       (PRN
#                         (, ,)
#                         (S (NP-SBJ (PRP you)) (VP (VBP know)))
#                         (, ,))
#                       (ADVP (RB again))
#                       (S
#                         (EDITED
#                           (RM (-DFL- \[))
#                           (NP-SBJ (PRP we))
#                           (, ,)
#                           (IP (-DFL- \+)))
#                         (NP-SBJ (PRP we))
#                         (RS (-DFL- \]))
#                         (VP
#                           (VP
#                             (VBP fit)
#                             (NP (DT that))
#                             (PP (IN in) (ADVP (RB there))))
#                           (CC or)
#                           (VP (FRAG (RB not)))))))))))))))
#   (. .)
#   (-DFL- E_S))
